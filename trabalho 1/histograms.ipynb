# %%
source = open('mean3_cameraman.pgm', 'rb')
# equal = open('equal_dog.pgm', 'rb')
# target = open()

print("P type:", source.readline()[:-1])
(width, height) = [int(i) for i in source.readline().split()]
max = int(source.readline())

print(f"w: {width}, h: {height}")
print(f"Max val: {max}")

import matplotlib.pyplot as plt

source_vals = plt.imread(source)

n, bins, patches = plt.hist(source_vals, facecolor='r')
# Out:
# P type: b'P2'
# w: 256, h: 256
# Max val: 255
